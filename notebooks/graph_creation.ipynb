# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from rpp_dock.data.dataset import parse_pdb
from rpp_dock.utils.graph_visualization import PlotlyVis

# %%
# %load_ext autoreload
# %autoreload 2

# %%
graph = parse_pdb(Path("../structures/1A2K_l_b.pdb"))
PlotlyVis.create_figure(graph)
